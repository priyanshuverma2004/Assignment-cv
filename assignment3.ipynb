# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshuverma2004/Assignment-cv/blob/main/assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": [],
      "authorship_tag": "ABX9TyMK8+Hx7mMesENP8KlSnp3R",
      "include_colab_link": True
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {
        "id": "view-in-github",
        "colab_type": "text"
      },
      "source": [
        "<a href=\"https://colab.research.google.com/github/SiddhantGodwani/Computer-Vision-/blob/main/Assignment3.ipynb\" target=\"_parent\"><img src=\"https://colab.research.google.com/assets/colab-badge.svg\" alt=\"Open In Colab\"/></a>"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": 35,
      "metadata": {
        "id": "mKXd3Z-915uW"
      },
      "outputs": [],
      "source": [
        "import numpy as np\n",
        "import tensorflow as tf\n",
        "from keras.datasets import mnist\n",
        "from tensorflow.keras.models import Sequential\n",
        "#from ann_visualizer.visualize import ann_via\n",
        "from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten\n",
        "from tensorflow.keras.utils import to_categorical\n",
        "import matplotlib.pyplot as plt"
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "from keras.callbacks import CSVLogger"
      ],
      "metadata": {
        "id": "xnPuNGnX3Aap"
      },
      "execution_count": 3,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "csv_logger=CSVLogger(\"model_history_log.csv\", append=True)"
      ],
      "metadata": {
        "id": "0IcuOCPf3jJF"
      },
      "execution_count": 5,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "(train_images, train_labels), (test_images, test_labels) = mnist.load_data()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "KFYJgDL4360u",
        "outputId": "1c85d579-7ff0-457c-9b25-64f07a8c0196"
      },
      "execution_count": 11,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz\n",
            "11490434/11490434 [==============================] - 0s 0us/step\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "#loding the images\n",
        "\n",
        "#train_images mnist.train_images()\n",
        "\n",
        "#train labels mnist.train labels()\n",
        "\n",
        "print(len(train_labels))\n",
        "\n",
        "#test_images mnist.test_images()\n",
        "\n",
        "#test_labels mnist.test_labels()\n",
        "\n",
        "print(len(test_labels))\n",
        "\n",
        "#Normalize the images. Pixel values are between 0-255 in image learning it is\n",
        "\n",
        "#good practice to normalize your data to a smaller range like between 0 and 1.\n",
        "\n",
        "train_images= (train_images/255)-0.5\n",
        "\n",
        "#print(train_images)\n",
        "\n",
        "test_images =(test_images/ 255) - 0.5\n",
        "\n",
        "#print(test_images)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "j7cXXiRH7Aju",
        "outputId": "89a098e2-3c2f-4ce9-e2b6-16809a157dd8"
      },
      "execution_count": 15,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "60000\n",
            "10000\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "#lets give the hyper parameters\n",
        "\n",
        "num_filters = 1\n",
        "\n",
        "filter_size = 9\n",
        "\n",
        "pool_size = 2\n",
        "\n",
        "# Model is being trained on 1875 batches of 32 im\n",
        "\n",
        "# Build the model.\n",
        "\n",
        "model = Sequential ([\n",
        "    Conv2D(num_filters, filter_size, input_shape=(28,28,1)),\n",
        "    MaxPooling2D(pool_size=pool_size),\n",
        "    Flatten(),\n",
        "    Dense (10, activation='softmax'),\n",
        "])"
      ],
      "metadata": {
        "id": "FGr8eZvz62Ix"
      },
      "execution_count": 16,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "# Compile the model.\n",
        "model.compile(\n",
        "    'adam',\n",
        "    loss='categorical_crossentropy',\n",
        "    metrics=['accuracy'],\n",
        "\n",
        ")"
      ],
      "metadata": {
        "id": "6ymHvvWa9NYf"
      },
      "execution_count": 19,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "tf.keras.callbacks.EarlyStopping(\n",
        "\n",
        "    monitor=\"loss\",\n",
        "    min_delta=0,\n",
        "    patience=0,\n",
        "    verbose=0,\n",
        "    mode=\"auto\",\n",
        "    baseline=None,\n",
        "    restore_best_weights=False, )"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "hBHbV0qW9o5x",
        "outputId": "95d700f1-06d9-41c5-ba71-4ca81b59fad6"
      },
      "execution_count": 20,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "<keras.src.callbacks.EarlyStopping at 0x7e1f9d78a1d0>"
            ]
          },
          "metadata": {},
          "execution_count": 20
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "callback_1 = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=2)"
      ],
      "metadata": {
        "id": "FUq27D0P9zrZ"
      },
      "execution_count": 21,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "#Train the model.\n",
        "\n",
        "history=  model.fit(\n",
        "    train_images,\n",
        "    to_categorical(train_labels),\n",
        "    epochs=10,\n",
        "    validation_data=(test_images, to_categorical(test_labels)),\n",
        "    callbacks=[csv_logger, callback_1],\n",
        "\n",
        ")"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "Q5E1FPxR9_2B",
        "outputId": "e4867011-634e-4e24-f144-2be49784af24"
      },
      "execution_count": 24,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Epoch 1/10\n",
            "1875/1875 [==============================] - 18s 9ms/step - loss: 0.5521 - accuracy: 0.8334 - val_loss: 0.3378 - val_accuracy: 0.9033\n",
            "Epoch 2/10\n",
            "1875/1875 [==============================] - 19s 10ms/step - loss: 0.3502 - accuracy: 0.8982 - val_loss: 0.3118 - val_accuracy: 0.9098\n",
            "Epoch 3/10\n",
            "1875/1875 [==============================] - 18s 10ms/step - loss: 0.3292 - accuracy: 0.9056 - val_loss: 0.2965 - val_accuracy: 0.9172\n",
            "Epoch 4/10\n",
            "1875/1875 [==============================] - 18s 10ms/step - loss: 0.3174 - accuracy: 0.9093 - val_loss: 0.2882 - val_accuracy: 0.9204\n",
            "Epoch 5/10\n",
            "1875/1875 [==============================] - 18s 10ms/step - loss: 0.3094 - accuracy: 0.9116 - val_loss: 0.2826 - val_accuracy: 0.9207\n",
            "Epoch 6/10\n",
            "1875/1875 [==============================] - 20s 11ms/step - loss: 0.3037 - accuracy: 0.9125 - val_loss: 0.2814 - val_accuracy: 0.9193\n",
            "Epoch 7/10\n",
            "1875/1875 [==============================] - 19s 10ms/step - loss: 0.2980 - accuracy: 0.9157 - val_loss: 0.2813 - val_accuracy: 0.9213\n",
            "Epoch 8/10\n",
            "1875/1875 [==============================] - 18s 10ms/step - loss: 0.2932 - accuracy: 0.9166 - val_loss: 0.2740 - val_accuracy: 0.9243\n",
            "Epoch 9/10\n",
            "1875/1875 [==============================] - 18s 10ms/step - loss: 0.2885 - accuracy: 0.9177 - val_loss: 0.2713 - val_accuracy: 0.9261\n",
            "Epoch 10/10\n",
            "1875/1875 [==============================] - 19s 10ms/step - loss: 0.2838 - accuracy: 0.9187 - val_loss: 0.2624 - val_accuracy: 0.9287\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "model.summary()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "8_nr7SvE-LIB",
        "outputId": "52c991a1-7762-4ef0-faa5-f3052537b8de"
      },
      "execution_count": 25,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Model: \"sequential\"\n",
            "_________________________________________________________________\n",
            " Layer (type)                Output Shape              Param #   \n",
            "=================================================================\n",
            " conv2d (Conv2D)             (None, 20, 20, 1)         82        \n",
            "                                                                 \n",
            " max_pooling2d (MaxPooling2  (None, 10, 10, 1)         0         \n",
            " D)                                                              \n",
            "                                                                 \n",
            " flatten (Flatten)           (None, 100)               0         \n",
            "                                                                 \n",
            " dense (Dense)               (None, 10)                1010      \n",
            "                                                                 \n",
            "=================================================================\n",
            "Total params: 1092 (4.27 KB)\n",
            "Trainable params: 1092 (4.27 KB)\n",
            "Non-trainable params: 0 (0.00 Byte)\n",
            "_________________________________________________________________\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "#Save the model:\n",
        "model.save_weights('cnn.h5')\n",
        "\n",
        "#Load the model's saved weights.\n",
        "model.load_weights('cnn.h5')"
      ],
      "metadata": {
        "id": "MuDTtzVm_kg-"
      },
      "execution_count": 26,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "# Predict on the first 10 test images.\n",
        "\n",
        "predictions= model.predict(test_images[:10])\n",
        "\n",
        "# Print our model's predictions.\n",
        "print(np.argmax(predictions, axis=1)) # [7, 2, 1, 0, 4]\n",
        "\n",
        "# Check our predictions against the ground truths.\n",
        "\n",
        "print(test_labels[:10]) # [7, 2, 1, 0, 41"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "YqrekOM2_mQ8",
        "outputId": "1402fda5-0f64-4bf3-d09e-3c960297fdb3"
      },
      "execution_count": 27,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "1/1 [==============================] - 0s 57ms/step\n",
            "[7 2 1 0 4 1 4 9 6 9]\n",
            "[7 2 1 0 4 1 4 9 5 9]\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "#Callback records events into a History object.\n",
        "\n",
        "accuracy = history.history['accuracy']\n",
        "\n",
        "val_accuracy=history.history['val_accuracy']\n",
        "\n",
        "loss= history.history['loss']\n",
        "\n",
        "val_loss = history.history['val_loss']"
      ],
      "metadata": {
        "id": "uex3z7eT_riB"
      },
      "execution_count": 38,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "#The range of epochs, from 1 to the total number of epochs, is often used to plot the learning curves of the model.\n",
        "\n",
        "#the range function is used to generate list of integers from 1 to the length of the accuracy list plus one. This is because the accuracy list is typically recorded at the and out each spoch, starting from the first epoch.\n",
        "\n",
        "epochs = range(1, len (accuracy) +1)\n",
        "\n",
        "plt.plot(epochs, accuracy, 'bo', label= 'Training acc')\n",
        "\n",
        "plt.plot(epochs, val_accuracy, 'b', label= 'Validation acc')\n",
        "\n",
        "plt.title('Training and validation accuracy')\n",
        "\n",
        "plt.legend()\n",
        "\n",
        "plt.figure()\n",
        "\n",
        "plt.plot(epochs, loss, 'bo', label = 'Training loss')\n",
        "plt.plot(epochs, val_loss, 'b', label='Validation lons')\n",
        "\n",
        "plt.title('Training and validation loss')\n",
        "\n",
        "plt.legend()\n",
        "\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 887
        },
        "id": "opGuaasJ_3Ha",
        "outputId": "5b851d99-35f9-4ec3-c272-c9ce1722c510"
      },
      "execution_count": 39,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 640x480 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {}
        },
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 640x480 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {}
        }
      ]
    }
  ]
}
# Out:
# {'nbformat': 4,
#  'nbformat_minor': 0,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyMK8+Hx7mMesENP8KlSnp3R',
#    'include_colab_link': True},
#   'kernelspec': {'name': 'python3', 'display_name': 'Python 3'},
#   'language_info': {'name': 'python'}},
#  'cells': [{'cell_type': 'markdown',
#    'metadata': {'id': 'view-in-github', 'colab_type': 'text'},
#    'source': ['<a href="https://colab.research.google.com/github/SiddhantGodwani/Computer-Vision-/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>']},
#   {'cell_type': 'code',
#    'execution_count': 35,
#    'metadata': {'id': 'mKXd3Z-915uW'},
#    'outputs': [],
#    'source': ['import numpy as np\n',
#     'import tensorflow as tf\n',
#     'from keras.datasets import mnist\n',
#     'from tensorflow.keras.models import Sequential\n',
#     '#from ann_visualizer.visualize import ann_via\n',
# ...
